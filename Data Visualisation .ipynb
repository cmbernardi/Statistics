# %% [markdown]
# # Visualizing Statistical Data

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Using Seaborn
# Seaborn comes with built-in data sets!

# %%
df = sns.load_dataset('tips')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %% [markdown]
# ## Histogram
# Using **distplot**

# %%
sns.distplot(df['total_bill'],bins=30, hist_kws=dict(edgecolor="k", linewidth=1))

# %% [markdown]
# To remove the kde layer and just have the histogram use:

# %%
sns.distplot(df['total_bill'],kde=False,bins=30, hist_kws=dict(edgecolor="k", linewidth=1))

# %% [markdown]
# ## Bar Chart
# Using **barplot**

# %%
sns.barplot(x='day',y='total_bill',data=df, palette="coolwarm")

# %% [markdown]
# Using **countplot**
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value.

# %%
sns.countplot(x='day',data=df, palette="coolwarm")

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(x="tip", y="total_bill", data=df)

# %% [markdown]
# Plot data and regression model fit with **lmplot**

# %%
sns.lmplot(x="tip", y="total_bill", data=df)

# %% [markdown]
# ## Line-plot

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")

# %% [markdown]
# ## Box-plot

# %%
sns.boxplot(x="day", y="total_bill", data=df ,palette='rainbow')

# %% [markdown]
# ## Violin-plot

# %%
sns.violinplot(x="day", y="total_bill", data=df ,palette='rainbow')
